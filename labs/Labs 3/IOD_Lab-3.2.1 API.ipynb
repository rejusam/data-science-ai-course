# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 3.2.1
# # *Querying the International Space Station*

# %% [markdown]
# ## The OpenNotify API

# %% [markdown]
# The OpenNotify API exposes a few attributes of the International Space Station (ISS) via a simple, authentication-free interface. The simplicity of this API precludes any need for a dedicated Python library. However, as with many APIs, it accepts requests according to HTTP standards and returns responses in JSON format, so the Python libraries request and json will make managing the I/O simpler still.

# %%
import requests
import json
from datetime import datetime, date, time

# %% [markdown]
# This request fetches the latest position of the international space station:

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")

# %% [markdown]
# Print the status code and text of the response:

# %%
#ANSWER
response.json()
# Out:
# {'iss_position': {'latitude': '44.5274', 'longitude': '-34.8123'},
#  'message': 'success',
#  'timestamp': 1775563233}

# %%
#ANSWER

# %% [markdown]
# We can use another API to request the current position of the ISS and the next few times at which it will be over a certain location. The latitude and longitude of Sydney are (-33.87, 151.21).

# %%
response = requests.get("https://api.g7vrd.co.uk/v1/satellite-passes/25544/-33.87/151.21.json?minelevation=0&hours=24")

# %% [markdown]
# Print the response headers:

# %%
#ANSWER
response.json()
# Out:
# {'api_status': 'ALPHA',
#  'request_timestamp': '2026-04-07T12:02:30.749431027Z',
#  'norad_id': 25544,
#  'satellite_name': 'ISS',
#  'tle_last_retrieved': '2026-04-06T22:50:19.513163687Z',
#  'lat': -33.87,
#  'lon': 151.21,
#  'hours': 24,
#  'min_elevation': 0,
#  'query_ms': 14,
#  'passes': [{'start': '2026-04-07T12:45:35.736Z',
#    'tca': '2026-04-07T12:49:05.736Z',
#    'end': '2026-04-07T12:53:05.736Z',
#    'aos_azimuth': 240,
#    'los_azimuth': 153,
#    'max_elevation': 6.0},
#   {'start': '2026-04-07T14:25:00.736Z',
#    'tca': '2026-04-07T14:28:00.736Z',
#    'end': '2026-04-07T14:30:45.736Z',
#    'aos_azimuth': 207,
#    'los_azimuth': 143,
#    'max_elevation': 3.0},
#   {'start': '2026-04-07T16:01:50.736Z',
#    'tca': '2026-04-07T16:06:20.736Z',
#    'end': '2026-04-07T16:10:35.736Z',
#    'aos_azimuth': 208,
#    'los_azimuth': 102,
#    'max_elevation': 10.0},
#   {'start': '2026-04-07T17:38:10.736Z',
#    'tca': '2026-04-07T17:43:40.736Z',
#    'end': '2026-04-07T17:49:05.736Z',
#    'aos_azimuth': 223,
#    'los_azimuth': 53,
#    'max_elevation': 60.0},
#   {'start': '2026-04-07T19:15:45.736Z',
#    'tca': '2026-04-07T19:20:15.736Z',
#    'end': '2026-04-07T19:24:20.736Z',
#    'aos_azimuth': 253,
#    'los_azimuth': 357,
#    'max_elevation': 10.0},
#   {'start': '2026-04-08T08:43:00.736Z',
#    'tca': '2026-04-08T08:47:30.736Z',
#    'end': '2026-04-08T08:52:20.736Z',
#    'aos_azimuth': 354,
#    'los_azimuth': 112,
#    'max_elevation': 14.0},
#   {'start': '2026-04-08T10:18:45.736Z',
#    'tca': '2026-04-08T10:24:15.736Z',
#    'end': '2026-04-08T10:29:35.736Z',
#    'aos_azimuth': 300,
#    'los_azimuth': 138,
#    'max_elevation': 44.0},
#   {'start': '2026-04-08T11:57:30.736Z',
#    'tca': '2026-04-08T12:01:30.736Z',
#    'end': '2026-04-08T12:05:55.736Z',
#    'aos_azimuth': 251,
#    'los_azimuth': 151,
#    'max_elevation': 8.0},
#   {'start': '2026-04-08T13:37:20.736Z',
#    'tca': '2026-04-08T13:40:20.736Z',
#    'end': '2026-04-08T13:43:00.736Z',
#    'aos_azimuth': 212,
#    'los_azimuth': 149,
#    'max_elevation': 3.0}]}

# %% [markdown]
# Print the content of the response (the data that the server returned):

# %%
#ANSWER

# %% [markdown]
# Print just the "content-type" value from the header:

# %%
#ANSWER

# %% [markdown]
# JSON was designed to be easy for computers to read, not for people. The `requests` library can decode the JSON byte string:

# %%
overheads = response.json()
print(overheads)
# Out:
# {'api_status': 'ALPHA', 'request_timestamp': '2026-04-07T12:02:30.749431027Z', 'norad_id': 25544, 'satellite_name': 'ISS', 'tle_last_retrieved': '2026-04-06T22:50:19.513163687Z', 'lat': -33.87, 'lon': 151.21, 'hours': 24, 'min_elevation': 0, 'query_ms': 14, 'passes': [{'start': '2026-04-07T12:45:35.736Z', 'tca': '2026-04-07T12:49:05.736Z', 'end': '2026-04-07T12:53:05.736Z', 'aos_azimuth': 240, 'los_azimuth': 153, 'max_elevation': 6.0}, {'start': '2026-04-07T14:25:00.736Z', 'tca': '2026-04-07T14:28:00.736Z', 'end': '2026-04-07T14:30:45.736Z', 'aos_azimuth': 207, 'los_azimuth': 143, 'max_elevation': 3.0}, {'start': '2026-04-07T16:01:50.736Z', 'tca': '2026-04-07T16:06:20.736Z', 'end': '2026-04-07T16:10:35.736Z', 'aos_azimuth': 208, 'los_azimuth': 102, 'max_elevation': 10.0}, {'start': '2026-04-07T17:38:10.736Z', 'tca': '2026-04-07T17:43:40.736Z', 'end': '2026-04-07T17:49:05.736Z', 'aos_azimuth': 223, 'los_azimuth': 53, 'max_elevation': 60.0}, {'start': '2026-04-07T19:15:45.736Z', 'tca': '2026-04-07T19:20:15.736Z', 'end': '2026-04-07T19:24:20.736Z', 'aos_azimuth': 253, 'los_azimuth': 357, 'max_elevation': 10.0}, {'start': '2026-04-08T08:43:00.736Z', 'tca': '2026-04-08T08:47:30.736Z', 'end': '2026-04-08T08:52:20.736Z', 'aos_azimuth': 354, 'los_azimuth': 112, 'max_elevation': 14.0}, {'start': '2026-04-08T10:18:45.736Z', 'tca': '2026-04-08T10:24:15.736Z', 'end': '2026-04-08T10:29:35.736Z', 'aos_azimuth': 300, 'los_azimuth': 138, 'max_elevation': 44.0}, {'start': '2026-04-08T11:57:30.736Z', 'tca': '2026-04-08T12:01:30.736Z', 'end': '2026-04-08T12:05:55.736Z', 'aos_azimuth': 251, 'los_azimuth': 151, 'max_elevation': 8.0}, {'start': '2026-04-08T13:37:20.736Z', 'tca': '2026-04-08T13:40:20.736Z', 'end': '2026-04-08T13:43:00.736Z', 'aos_azimuth': 212, 'los_azimuth': 149, 'max_elevation': 3.0}]}

# %% [markdown]
# What kind of object did this give us?

# %%
#ANSWER:

# %% [markdown]
# Python dicts are easier to work with, but the data we want is still buried in that data structure, so we have to dig it out. First, extract the `passes` value to a separate list:

# %%
#ANSWER:

# %% [markdown]
# Now extract the `start` strings into an array called `srisetimes`:

# %%
#ANSWER:

# %% [markdown]
# These are strings. We convert these to an array of Python `datetime` values called `risetimes`:

# %%
srisetimes = [datetime.strptime(xpass['start'], "%Y-%m-%dT%H:%M:%S.%fZ") for xpass in passes]

# %% [markdown]
# Finally, use `risetime.strftime` to print these in a format that people understand:
#
# ```
# e.g.
# 13/04/26 06:24
# 13/04/26 07:58
# 13/04/26 09:37
# 13/04/26 11:16
# 13/04/26 12:54
# 13/04/26 02:31
# ```

# %%
#ANSWER:

# %% [markdown]
# Finally, here is an endpoint that tells us who is on board:

# %%
response = requests.get("http://api.open-notify.org/astros.json")

# %% [markdown]
# Referring to the methods used above, extract the number of astronauts and their names:

# %%
#ANSWER:
response.json()
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'},
#   {'craft': 'ISS', 'name': 'Nikolai Chub'},
#   {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'},
#   {'craft': 'ISS', 'name': 'Matthew Dominick'},
#   {'craft': 'ISS', 'name': 'Michael Barratt'},
#   {'craft': 'ISS', 'name': 'Jeanette Epps'},
#   {'craft': 'ISS', 'name': 'Alexander Grebenkin'},
#   {'craft': 'ISS', 'name': 'Butch Wilmore'},
#   {'craft': 'ISS', 'name': 'Sunita Williams'},
#   {'craft': 'Tiangong', 'name': 'Li Guangsu'},
#   {'craft': 'Tiangong', 'name': 'Li Cong'},
#   {'craft': 'Tiangong', 'name': 'Ye Guangfu'}],
#  'number': 12,
#  'message': 'success'}

# %% [markdown]
# ## HOMEWORK

# %% [markdown]
# 1. Write a simple handler for the response status code (refer to lab resources slide for HTTP response codes). As this Jupyter Notebook is an interactive device, the handler does not need to manage subsequent code execution (i.e. by branching or aborting execution), although it should return something that could be used to do so if deployed in a Python program.

# %%
#ANSWER:
def handleResponse(response, verbose = False):
    '''
    Returns Boolean Value, Status Code,
    '''
    
  # if Status Code is 200 return false, and status code
  # Otherwise Return True and Status Code

# %% [markdown]
# 2. Test your response handler on some correct and incorrect API calls.

# %%
response = requests.get("http://api.open-notify.org/astros.json")
if handleResponse(response)[0]:
    print('API call failed. Resolve issue before continuing!')

response = requests.get("http://api.open-notify.org/iss-now.json")
handleResponse(response, True)[0]
# Out:
# Success: 200
# False

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2026 Institute of Data
#
#
# ---
#
#
#
# ---
